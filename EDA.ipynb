# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
sales=pd.read_csv("sales data-set.csv")
features=pd.read_csv("Features data set.csv")
stores=pd.read_csv("stores data-set.csv")

# %%
print(stores.shape)
print(features.shape)
print(sales.shape)
# Out:
# (44, 3)
# (8008, 12)
# (414819, 5)

# %%
features
# Out:
#       Store        Date  Temperature  Fuel_Price  MarkDown1  MarkDown2  \
# 0         1  05-02-2010        31.53       2.666        NaN        NaN
# 1         1  12-02-2010        33.16       2.671        NaN        NaN
# 2         1  19-02-2010        35.70       2.654        NaN        NaN
# 3         1  26-02-2010        29.98       2.667        NaN        NaN
# 4         1  05-03-2010        40.65       2.681        NaN        NaN
# ...     ...         ...          ...         ...        ...        ...
# 8003     44  28-06-2013        90.28       3.781    1053.69        NaN
# 8004     44  05-07-2013        93.54       3.753     360.49        NaN
# 8005     44  12-07-2013        87.18       3.737      51.96        NaN
# 8006     44  19-07-2013        87.09       3.823     211.63        NaN
# 8007     44  26-07-2013        83.32       3.865        NaN        NaN
#
#       MarkDown3  MarkDown4  MarkDown5         CPI  Unemployment  IsHoliday
# 0           NaN        NaN        NaN  126.442065         8.119      False
# 1           NaN        NaN        NaN  126.496258         8.119       True
# 2           NaN        NaN        NaN  126.526286         8.119      False
# 3           NaN        NaN        NaN  126.552286         8.119      False
# 4           NaN        NaN        NaN  126.578286         8.119      False
# ...         ...        ...        ...         ...           ...        ...
# 8003        NaN        NaN    4143.90         NaN           NaN      False
# 8004      48.46     313.04    1007.61         NaN           NaN      False
# 8005       9.98        NaN    1346.73         NaN           NaN      False
# 8006       3.71        NaN     478.31         NaN           NaN      False
# 8007       0.17        NaN     756.79         NaN           NaN      False
#
# [8008 rows x 12 columns]

# %%
merged=sales.merge(stores,how='left')

# %%
merged
# Out:
#         Store  Dept        Date  Weekly_Sales  IsHoliday Type   Size
# 0           1     1  05-02-2010       6871.20      False    C  39910
# 1           1     1  12-02-2010      12315.65       True    C  39910
# 2           1     1  19-02-2010       7751.11      False    C  39910
# 3           1     1  26-02-2010       6014.71      False    C  39910
# 4           1     1  05-03-2010       6120.60      False    C  39910
# ...       ...   ...         ...           ...        ...  ...    ...
# 414814     44    98  28-09-2012       5701.87      False    C  39690
# 414815     44    98  05-10-2012       5601.47      False    C  39690
# 414816     44    98  12-10-2012       5971.28      False    C  39690
# 414817     44    98  19-10-2012       5960.84      False    C  39690
# 414818     44    98  26-10-2012       6567.83      False    C  39690
#
# [414819 rows x 7 columns]

# %%
merged=merged.merge(features,how='left')

# %%
merged
# Out:
#         Store  Dept        Date  Weekly_Sales  IsHoliday Type   Size  \
# 0           1     1  05-02-2010       6871.20      False    C  39910
# 1           1     1  12-02-2010      12315.65       True    C  39910
# 2           1     1  19-02-2010       7751.11      False    C  39910
# 3           1     1  26-02-2010       6014.71      False    C  39910
# 4           1     1  05-03-2010       6120.60      False    C  39910
# ...       ...   ...         ...           ...        ...  ...    ...
# 414814     44    98  28-09-2012       5701.87      False    C  39690
# 414815     44    98  05-10-2012       5601.47      False    C  39690
# 414816     44    98  12-10-2012       5971.28      False    C  39690
# 414817     44    98  19-10-2012       5960.84      False    C  39690
# 414818     44    98  26-10-2012       6567.83      False    C  39690
#
#         Temperature  Fuel_Price  MarkDown1  MarkDown2  MarkDown3  MarkDown4  \
# 0             31.53       2.666        NaN        NaN        NaN        NaN
# 1             33.16       2.671        NaN        NaN        NaN        NaN
# 2             35.70       2.654        NaN        NaN        NaN        NaN
# 3             29.98       2.667        NaN        NaN        NaN        NaN
# 4             40.65       2.681        NaN        NaN        NaN        NaN
# ...             ...         ...        ...        ...        ...        ...
# 414814        82.52       3.966     123.87        NaN        NaN        NaN
# 414815        80.88       4.132     479.07        NaN       6.00      10.64
# 414816        76.03       4.468      49.38        NaN      10.87        NaN
# 414817        72.71       4.449      56.03        NaN       8.69        NaN
# 414818        70.50       4.301        NaN       0.75       2.00        NaN
#
#         MarkDown5         CPI  Unemployment
# 0             NaN  126.442065         8.119
# 1             NaN  126.496258         8.119
# 2             NaN  126.526286         8.119
# 3             NaN  126.552286         8.119
# 4             NaN  126.578286         8.119
# ...           ...         ...           ...
# 414814     548.02  131.043000         7.170
# 414815    2565.13  131.075667         6.943
# 414816     970.72  131.108333         6.943
# 414817     455.38  131.149968         6.943
# 414818    1034.55  131.193097         6.943
#
# [414819 rows x 16 columns]

# %%
merged['Date']=pd.to_datetime(merged['Date'])
# Out:
# C:\Users\sheth\.conda\envs\MLprojectsENV\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '19-02-2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\sheth\.conda\envs\MLprojectsENV\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '26-02-2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\sheth\.conda\envs\MLprojectsENV\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '19-03-2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\sheth\.conda\envs\MLprojectsENV\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '26-03-2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\sheth\.conda\envs\MLprojectsENV\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '16-04-2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\sheth\.conda\envs\MLprojectsENV\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '23-04-2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\sheth\.conda\envs\MLprojectsENV\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '30-04-2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\sheth\.conda\envs\MLprojectsENV\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '14-05-2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\sheth\.conda\envs\MLprojectsENV\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '21-05-2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\sheth\.conda\envs\MLprojectsENV\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '28-05-2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\sheth\.conda\envs\MLprojectsENV\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '18-06-2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\sheth\.conda\envs\MLprojectsENV\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '25-06-2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\sheth\.conda\envs\MLprojectsENV\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '16-07-2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\sheth\.conda\envs\MLprojectsENV\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '23-07-2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\sheth\.conda\envs\MLprojectsENV\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '30-07-2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\sheth\.conda\envs\MLprojectsENV\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '13-08-2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\sheth\.conda\envs\MLprojectsENV\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '20-08-2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\sheth\.conda\envs\MLprojectsENV\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '27-08-2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\sheth\.conda\envs\MLprojectsENV\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '17-09-2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\sheth\.conda\envs\MLprojectsENV\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '24-09-2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\sheth\.conda\envs\MLprojectsENV\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '15-10-2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\sheth\.conda\envs\MLprojectsENV\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '22-10-2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\sheth\.conda\envs\MLprojectsENV\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '29-10-2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\sheth\.conda\envs\MLprojectsENV\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '19-11-2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\sheth\.conda\envs\MLprojectsENV\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '26-11-2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\sheth\.conda\envs\MLprojectsENV\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '17-12-2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\sheth\.conda\envs\MLprojectsENV\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '24-12-2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\sheth\.conda\envs\MLprojectsENV\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '31-12-2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\sheth\.conda\envs\MLprojectsENV\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '14-01-2011' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\sheth\.conda\envs\MLprojectsENV\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '21-01-2011' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\sheth\.conda\envs\MLprojectsENV\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '28-01-2011' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\sheth\.conda\envs\MLprojectsENV\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '18-02-2011' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\sheth\.conda\envs\MLprojectsENV\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '25-02-2011' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\sheth\.conda\envs\MLprojectsENV\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '18-03-2011' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\sheth\.conda\envs\MLprojectsENV\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '25-03-2011' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\sheth\.conda\envs\MLprojectsENV\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '15-04-2011' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\sheth\.conda\envs\MLprojectsENV\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '22-04-2011' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\sheth\.conda\envs\MLprojectsENV\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '29-04-2011' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\sheth\.conda\envs\MLprojectsENV\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '13-05-2011' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\sheth\.conda\envs\MLprojectsENV\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '20-05-2011' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\sheth\.conda\envs\MLprojectsENV\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '27-05-2011' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\sheth\.conda\envs\MLprojectsENV\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '17-06-2011' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\sheth\.conda\envs\MLprojectsENV\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '24-06-2011' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\sheth\.conda\envs\MLprojectsENV\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '15-07-2011' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\sheth\.conda\envs\MLprojectsENV\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '22-07-2011' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\sheth\.conda\envs\MLprojectsENV\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '29-07-2011' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\sheth\.conda\envs\MLprojectsENV\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '19-08-2011' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\sheth\.conda\envs\MLprojectsENV\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '26-08-2011' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\sheth\.conda\envs\MLprojectsENV\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '16-09-2011' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\sheth\.conda\envs\MLprojectsENV\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '23-09-2011' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\sheth\.conda\envs\MLprojectsENV\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '30-09-2011' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\sheth\.conda\envs\MLprojectsENV\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '14-10-2011' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\sheth\.conda\envs\MLprojectsENV\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '21-10-2011' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\sheth\.conda\envs\MLprojectsENV\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '28-10-2011' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\sheth\.conda\envs\MLprojectsENV\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '18-11-2011' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\sheth\.conda\envs\MLprojectsENV\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '25-11-2011' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\sheth\.conda\envs\MLprojectsENV\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '16-12-2011' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\sheth\.conda\envs\MLprojectsENV\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '23-12-2011' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\sheth\.conda\envs\MLprojectsENV\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '30-12-2011' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\sheth\.conda\envs\MLprojectsENV\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '13-01-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\sheth\.conda\envs\MLprojectsENV\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '20-01-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\sheth\.conda\envs\MLprojectsENV\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '27-01-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\sheth\.conda\envs\MLprojectsENV\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '17-02-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\sheth\.conda\envs\MLprojectsENV\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '24-02-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\sheth\.conda\envs\MLprojectsENV\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '16-03-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\sheth\.conda\envs\MLprojectsENV\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '23-03-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\sheth\.conda\envs\MLprojectsENV\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '30-03-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\sheth\.conda\envs\MLprojectsENV\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '13-04-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\sheth\.conda\envs\MLprojectsENV\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '20-04-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\sheth\.conda\envs\MLprojectsENV\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '27-04-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\sheth\.conda\envs\MLprojectsENV\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '18-05-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\sheth\.conda\envs\MLprojectsENV\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '25-05-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\sheth\.conda\envs\MLprojectsENV\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '15-06-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\sheth\.conda\envs\MLprojectsENV\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '22-06-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\sheth\.conda\envs\MLprojectsENV\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '29-06-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\sheth\.conda\envs\MLprojectsENV\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '13-07-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\sheth\.conda\envs\MLprojectsENV\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '20-07-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\sheth\.conda\envs\MLprojectsENV\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '27-07-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\sheth\.conda\envs\MLprojectsENV\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '17-08-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\sheth\.conda\envs\MLprojectsENV\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '24-08-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\sheth\.conda\envs\MLprojectsENV\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '31-08-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\sheth\.conda\envs\MLprojectsENV\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '14-09-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\sheth\.conda\envs\MLprojectsENV\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '21-09-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\sheth\.conda\envs\MLprojectsENV\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '28-09-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\sheth\.conda\envs\MLprojectsENV\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '19-10-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\sheth\.conda\envs\MLprojectsENV\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '26-10-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)

# %%
merged.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 414819 entries, 0 to 414818
# Data columns (total 16 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   Store         414819 non-null  int64
#  1   Dept          414819 non-null  int64
#  2   Date          414819 non-null  datetime64[ns]
#  3   Weekly_Sales  414819 non-null  float64
#  4   IsHoliday     414819 non-null  bool
#  5   Type          414819 non-null  object
#  6   Size          414819 non-null  int64
#  7   Temperature   414819 non-null  float64
#  8   Fuel_Price    414819 non-null  float64
#  9   MarkDown1     148271 non-null  float64
#  10  MarkDown2     110542 non-null  float64
#  11  MarkDown3     135055 non-null  float64
#  12  MarkDown4     134680 non-null  float64
#  13  MarkDown5     149022 non-null  float64
#  14  CPI           414819 non-null  float64
#  15  Unemployment  414819 non-null  float64
# dtypes: bool(1), datetime64[ns](1), float64(10), int64(3), object(1)
# memory usage: 51.0+ MB

# %%
merged['date_year']=merged['Date'].dt.year

# %%
merged['date_month']=merged['Date'].dt.month

# %%
merged['date_day']=merged['Date'].dt.day

# %%
merged['date_week']=merged['Date'].dt.isocalendar().week

# %%
merged.head()
# Out:
#    Store  Dept       Date  Weekly_Sales  IsHoliday Type   Size  Temperature  \
# 0      1     1 2010-05-02       6871.20      False    C  39910        31.53
# 1      1     1 2010-12-02      12315.65       True    C  39910        33.16
# 2      1     1 2010-02-19       7751.11      False    C  39910        35.70
# 3      1     1 2010-02-26       6014.71      False    C  39910        29.98
# 4      1     1 2010-05-03       6120.60      False    C  39910        40.65
#
#    Fuel_Price  MarkDown1  MarkDown2  MarkDown3  MarkDown4  MarkDown5  \
# 0       2.666        NaN        NaN        NaN        NaN        NaN
# 1       2.671        NaN        NaN        NaN        NaN        NaN
# 2       2.654        NaN        NaN        NaN        NaN        NaN
# 3       2.667        NaN        NaN        NaN        NaN        NaN
# 4       2.681        NaN        NaN        NaN        NaN        NaN
#
#           CPI  Unemployment  date_year  date_month  date_day  date_week
# 0  126.442065         8.119       2010           5         2         17
# 1  126.496258         8.119       2010          12         2         48
# 2  126.526286         8.119       2010           2        19          7
# 3  126.552286         8.119       2010           2        26          8
# 4  126.578286         8.119       2010           5         3         18

# %%
merged.isnull().sum()
# Out:
# Store                0
# Dept                 0
# Date                 0
# Weekly_Sales         0
# IsHoliday            0
# Type                 0
# Size                 0
# Temperature          0
# Fuel_Price           0
# MarkDown1       266548
# MarkDown2       304277
# MarkDown3       279764
# MarkDown4       280139
# MarkDown5       265797
# CPI                  0
# Unemployment         0
# date_year            0
# date_month           0
# date_day             0
# date_week            0
# dtype: int64

# %%
merged['Type'].value_counts()
# Out:
# A    215478
# B    163495
# C     35846
# Name: Type, dtype: int64

# %%
merged= pd.get_dummies(data=merged, columns=['Type'])

# %%
merged.corr()
# Out:
#                  Store      Dept  Weekly_Sales  IsHoliday      Size  \
# Store         1.000000  0.019632     -0.042176  -0.000403 -0.019362
# Dept          0.019632  1.000000      0.142710   0.000969 -0.000610
# Weekly_Sales -0.042176  0.142710      1.000000   0.012951  0.247615
# IsHoliday    -0.000403  0.000969      0.012951   1.000000  0.000565
# Size         -0.019362 -0.000610      0.247615   0.000565  1.000000
# Temperature  -0.034982  0.003843     -0.001508  -0.155682 -0.047444
# Fuel_Price    0.075976  0.004340     -0.000542  -0.078289 -0.004728
# MarkDown1    -0.064369 -0.001416      0.084553  -0.036042  0.332951
# MarkDown2    -0.024540  0.000434      0.023921   0.335342  0.106660
# MarkDown3    -0.013864  0.001975      0.060433   0.430728  0.046134
# MarkDown4     0.000496  0.004356      0.045265   0.000512  0.166792
# MarkDown5     0.037108  0.000807      0.090034  -0.053944  0.296986
# CPI          -0.212813 -0.009026     -0.019462  -0.001907  0.021076
# Unemployment  0.197077  0.006368     -0.024293   0.010518 -0.042466
# date_year     0.002468  0.004023     -0.010133  -0.056816 -0.005343
# date_month    0.000135  0.001039      0.025315   0.332804 -0.000242
# date_day      0.000141 -0.000718     -0.004945  -0.035299 -0.000750
# date_week     0.000176  0.001035      0.024781   0.329415 -0.000367
# Type_A        0.141816  0.013944      0.186396   0.000429  0.758590
# Type_B       -0.274859 -0.029214     -0.134292   0.000146 -0.488320
# Type_C        0.225855  0.026014     -0.097887  -0.001017 -0.499631
#
#               Temperature  Fuel_Price  MarkDown1  MarkDown2  MarkDown3  ...  \
# Store           -0.034982    0.075976  -0.064369  -0.024540  -0.013864  ...
# Dept             0.003843    0.004340  -0.001416   0.000434   0.001975  ...
# Weekly_Sales    -0.001508   -0.000542   0.084553   0.023921   0.060433  ...
# IsHoliday       -0.155682   -0.078289  -0.036042   0.335342   0.430728  ...
# Size            -0.047444   -0.004728   0.332951   0.106660   0.046134  ...
# Temperature      1.000000    0.145916  -0.035519  -0.324536  -0.096597  ...
# Fuel_Price       0.145916    1.000000   0.054238  -0.222796  -0.104245  ...
# MarkDown1       -0.035519    0.054238   1.000000   0.022986  -0.110722  ...
# MarkDown2       -0.324536   -0.222796   0.022986   1.000000  -0.050398  ...
# MarkDown3       -0.096597   -0.104245  -0.110722  -0.050398   1.000000  ...
# MarkDown4       -0.063445   -0.045576   0.819187  -0.007933  -0.071264  ...
# MarkDown5       -0.013798   -0.134408   0.153827  -0.008491  -0.027902  ...
# CPI              0.177246   -0.163093  -0.043370  -0.037971  -0.021633  ...
# Unemployment     0.090136   -0.029448   0.068475   0.023461   0.015768  ...
# date_year        0.066076    0.779774   0.142990  -0.222949  -0.321571  ...
# date_month       0.066459   -0.051444  -0.155236   0.107100   0.166219  ...
# date_day         0.089227    0.032739  -0.303993   0.018747   0.147895  ...
# date_week        0.073219   -0.040527  -0.177618   0.104959   0.173739  ...
# Type_A           0.032920   -0.043872   0.165988   0.049003   0.020511  ...
# Type_B          -0.104124    0.033713  -0.024372  -0.024712   0.001887  ...
# Type_C           0.122554    0.019379  -0.254767  -0.062686  -0.042350  ...
#
#               MarkDown5       CPI  Unemployment  date_year  date_month  \
# Store          0.037108 -0.212813      0.197077   0.002468    0.000135
# Dept           0.000807 -0.009026      0.006368   0.004023    0.001039
# Weekly_Sales   0.090034 -0.019462     -0.024293  -0.010133    0.025315
# IsHoliday     -0.053944 -0.001907      0.010518  -0.056816    0.332804
# Size           0.296986  0.021076     -0.042466  -0.005343   -0.000242
# Temperature   -0.013798  0.177246      0.090136   0.066076    0.066459
# Fuel_Price    -0.134408 -0.163093     -0.029448   0.779774   -0.051444
# MarkDown1      0.153827 -0.043370      0.068475   0.142990   -0.155236
# MarkDown2     -0.008491 -0.037971      0.023461  -0.222949    0.107100
# MarkDown3     -0.027902 -0.021633      0.015768  -0.321571    0.166219
# MarkDown4      0.107183 -0.048647      0.026397   0.126587   -0.175364
# MarkDown5      1.000000  0.069908      0.007713  -0.129749   -0.023955
# CPI            0.069908  1.000000     -0.321265   0.074204    0.001741
# Unemployment   0.007713 -0.321265      1.000000  -0.240070   -0.001966
# date_year     -0.129749  0.074204     -0.240070   1.000000   -0.138844
# date_month    -0.023955  0.001741     -0.001966  -0.138844    1.000000
# date_day      -0.091408  0.004008     -0.007839  -0.013478    0.006714
# date_week     -0.031063  0.003037     -0.005870  -0.126856    0.996486
# Type_A         0.227426  0.100842     -0.076339  -0.002634    0.000460
# Type_B        -0.133852 -0.070604      0.000285  -0.000854   -0.000112
# Type_C        -0.170024 -0.056522      0.135249   0.006168   -0.000623
#
#               date_day  date_week    Type_A    Type_B    Type_C
# Store         0.000141   0.000176  0.141816 -0.274859  0.225855
# Dept         -0.000718   0.001035  0.013944 -0.029214  0.026014
# Weekly_Sales -0.004945   0.024781  0.186396 -0.134292 -0.097887
# IsHoliday    -0.035299   0.329415  0.000429  0.000146 -0.001017
# Size         -0.000750  -0.000367  0.758590 -0.488320 -0.499631
# Temperature   0.089227   0.073219  0.032920 -0.104124  0.122554
# Fuel_Price    0.032739  -0.040527 -0.043872  0.033713  0.019379
# MarkDown1    -0.303993  -0.177618  0.165988 -0.024372 -0.254767
# MarkDown2     0.018747   0.104959  0.049003 -0.024712 -0.062686
# MarkDown3     0.147895   0.173739  0.020511  0.001887 -0.042350
# MarkDown4    -0.320395  -0.200080  0.090809 -0.064477 -0.084973
# MarkDown5    -0.091408  -0.031063  0.227426 -0.133852 -0.170024
# CPI           0.004008   0.003037  0.100842 -0.070604 -0.056522
# Unemployment -0.007839  -0.005870 -0.076339  0.000285  0.135249
# date_year    -0.013478  -0.126856 -0.002634 -0.000854  0.006168
# date_month    0.006714   0.996486  0.000460 -0.000112 -0.000623
# date_day      1.000000   0.088133 -0.000589  0.000567  0.000061
# date_week     0.088133   1.000000  0.000380 -0.000076 -0.000544
# Type_A       -0.000589   0.000380  1.000000 -0.838568 -0.319756
# Type_B        0.000567  -0.000076 -0.838568  1.000000 -0.248057
# Type_C        0.000061  -0.000544 -0.319756 -0.248057  1.000000
#
# [21 rows x 21 columns]

# %%
sns.scatterplot(x='Unemployment', y='Weekly_Sales', data=merged);

# %%
sns.scatterplot(x='Temperature', y='Weekly_Sales', data=merged);

# %%
sns.scatterplot(x='Fuel_Price', y='Weekly_Sales', data=merged);

# %%
sns.scatterplot(x='CPI', y='Weekly_Sales', data=merged);

# %%
sns.set(rc={'figure.figsize':(6,4)})
sns.scatterplot(x='MarkDown1', y='Date',hue='IsHoliday', data=merged);

# %%
sns.set(rc={'figure.figsize':(6,4)})
sns.scatterplot(x='MarkDown2', y='Date',hue='IsHoliday', data=merged);

# %%
sns.set(rc={'figure.figsize':(6,4)})
sns.scatterplot(x='MarkDown3', y='Date',hue='IsHoliday', data=merged);

# %%
sns.set(rc={'figure.figsize':(6,4)})
sns.scatterplot(x='MarkDown4', y='Date',hue='IsHoliday', data=merged);

# %%
sns.set(rc={'figure.figsize':(6,4)})
sns.scatterplot(x='MarkDown5', y='Date',hue='IsHoliday', data=merged);

# %%
sns.set(rc = {'figure.figsize':(15,8)})
sns.heatmap(merged.corr())
# Out:
# <AxesSubplot:>

# %%
sns.heatmap(merged.isnull(),yticklabels=False,cbar=False,cmap='viridis')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [60], in <cell line: 1>()
# ----> 1 sns.heatmap(merged.isnull(),yticklabels=False,cbar=False,cmap='viridis',rc = {'figure.figsize':(15,8)})
#
# File ~\.conda\envs\MLprojectsENV\lib\site-packages\seaborn\_decorators.py:46, in _deprecate_positional_args.<locals>.inner_f(*args, **kwargs)
#      36     warnings.warn(
#      37         "Pass the following variable{} as {}keyword arg{}: {}. "
#      38         "From version 0.12, the only valid positional argument "
#    (...)
#      43         FutureWarning
#      44     )
#      45 kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46 return f(**kwargs)
#
# File ~\.conda\envs\MLprojectsENV\lib\site-packages\seaborn\matrix.py:553, in heatmap(data, vmin, vmax, cmap, center, robust, annot, fmt, annot_kws, linewidths, linecolor, cbar, cbar_kws, cbar_ax, square, xticklabels, yticklabels, mask, ax, **kwargs)
#     551 if square:
#     552     ax.set_aspect("equal")
# --> 553 plotter.plot(ax, cbar_ax, kwargs)
#     554 return ax
#
# File ~\.conda\envs\MLprojectsENV\lib\site-packages\seaborn\matrix.py:302, in _HeatMapper.plot(self, ax, cax, kws)
#     299     kws.setdefault("vmax", self.vmax)
#     301 # Draw the heatmap
# --> 302 mesh = ax.pcolormesh(self.plot_data, cmap=self.cmap, **kws)
#     304 # Set the axis limits
#     305 ax.set(xlim=(0, self.data.shape[1]), ylim=(0, self.data.shape[0]))
#
# File ~\.conda\envs\MLprojectsENV\lib\site-packages\matplotlib\__init__.py:1412, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1409 @functools.wraps(func)
#    1410 def inner(ax, *args, data=None, **kwargs):
#    1411     if data is None:
# -> 1412         return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1414     bound = new_sig.bind(ax, *args, **kwargs)
#    1415     auto_label = (bound.arguments.get(label_namer)
#    1416                   or bound.kwargs.get(label_namer))
#
# File ~\.conda\envs\MLprojectsENV\lib\site-packages\matplotlib\axes\_axes.py:6070, in Axes.pcolormesh(self, alpha, norm, cmap, vmin, vmax, shading, antialiased, *args, **kwargs)
#    6066 C = C.ravel()
#    6068 kwargs.setdefault('snap', rcParams['pcolormesh.snap'])
# -> 6070 collection = mcoll.QuadMesh(
#    6071     coords, antialiased=antialiased, shading=shading,
#    6072     array=C, cmap=cmap, norm=norm, alpha=alpha, **kwargs)
#    6073 collection._scale_norm(norm, vmin, vmax)
#    6074 self._pcolor_grid_deprecation_helper()
#
# File ~\.conda\envs\MLprojectsENV\lib\site-packages\matplotlib\collections.py:2016, in QuadMesh.__init__(self, *args, **kwargs)
#    2013 self._bbox.update_from_data_xy(self._coordinates.reshape(-1, 2))
#    2014 # super init delayed after own init because array kwarg requires
#    2015 # self._coordinates and self._shading
# -> 2016 super().__init__(**kwargs)
#
# File ~\.conda\envs\MLprojectsENV\lib\site-packages\matplotlib\collections.py:221, in Collection.__init__(self, edgecolors, facecolors, linewidths, linestyles, capstyle, joinstyle, antialiaseds, offsets, transOffset, norm, cmap, pickradius, hatch, urls, zorder, **kwargs)
#     218 self._transOffset = transOffset
#     220 self._path_effects = None
# --> 221 self.update(kwargs)
#     222 self._paths = None
#
# File ~\.conda\envs\MLprojectsENV\lib\site-packages\matplotlib\artist.py:1064, in Artist.update(self, props)
#    1062             func = getattr(self, f"set_{k}", None)
#    1063             if not callable(func):
# -> 1064                 raise AttributeError(f"{type(self).__name__!r} object "
#    1065                                      f"has no property {k!r}")
#    1066             ret.append(func(v))
#    1067 if ret:
#
# AttributeError: 'QuadMesh' object has no property 'rc'

# %%
merged=merged.fillna(0)

# %%
merged = merged.drop(['Date', 'Temperature','Fuel_Price', 'MarkDown1', 'MarkDown2', 'MarkDown3',
             'MarkDown4', 'MarkDown5', 'CPI', 'Unemployment', 'date_month', 'date_day' ], axis=1)

# %%
X=merged.drop(['Weekly_Sales'],axis=1)

# %%
merged.info()

# %%
y=merged['Weekly_Sales']

# %%
merged.info()

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression #never use tthis linear regression in scikit learn
import numpy as np
from sklearn.linear_model import Ridge
from sklearn.metrics import classification_report
from sklearn.metrics import accuracy_score
from sklearn.metrics import mean_squared_error

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)

# %%
from sklearn.preprocessing import StandardScaler
from sklearn import preprocessing
X_train = preprocessing.StandardScaler().fit(X_train).transform(X_train.astype(float))

# %%
X_test = preprocessing.StandardScaler().fit(X_test).transform(X_test.astype(float))

# %%
def WMAE(df, targets, predictions):
    weights = df.IsHoliday.apply(lambda x: 5 if x else 1)
    return np.round(np.sum(weights*abs(targets-predictions))/(np.sum(weights)), 2)

# %%
lr_regressor = LinearRegression()
linreg_model= lr_regressor.fit(X_train,y_train) 
print(linreg_model.score(X_train,y_train)) #R^2
linreg_model.score(X_test,y_test) #R^2

# %%
train_preds = linreg_model.predict(X_train)
val_preds = linreg_model.predict(X_test)
train_rmse = mean_squared_error(y_train, train_preds, squared=False)
val_rmse = mean_squared_error(y_test, val_preds, squared=False)
linreg_model.score(X_test,y_test) #R^2
print('RMSE Score on test data',val_rmse)
print('RMSE Score on train data',train_rmse)
train_wmae = WMAE(X_train, y_train, train_preds)
print('The WMAE loss for the training set is  {}.'.format(train_wmae))
# Compute WMAE on validation data
val_wmae = WMAE(X_test, y_test, val_preds)
print('The WMAE loss for the validation set is  {}.'.format(val_wmae))

# %%
X_train['IsHoliday']

# %%
ridge_regressor1 = Ridge(alpha=1000) #alpha is optional large alpha values strong regularization play with alpha stronger alpha less coefficnet values
ridge_model= ridge_regressor1.fit(X_train,y_train) 
ridge_model.score(X_train,y_train) #R^2

# %%
train_preds = ridge_model.predict(X_train)
val_preds = ridge_model.predict(X_test)
train_rmse = mean_squared_error(y_train, train_preds, squared=False)
val_rmse = mean_squared_error(y_test, val_preds, squared=False)
ridge_model.score(X_test,y_test) #R^2
print('RMSE Score on test data',val_rmse)
print('RMSE Score on train data',train_rmse)
train_wmae = WMAE(X_train, y_train, train_preds)
print('The WMAE loss for the training set is  {}.'.format(train_wmae))
# Compute WMAE on validation data
val_wmae = WMAE(X_test, y_test, val_preds)
print('The WMAE loss for the validation set is  {}.'.format(val_wmae))

# %%
from sklearn.tree import DecisionTreeRegressor
tree = DecisionTreeRegressor()
tree_model=tree.fit(X_train, y_train)

# %%
train_preds = tree_model.predict(X_train)
val_preds = tree_model.predict(X_test)
train_rmse = mean_squared_error(y_train, train_preds, squared=False)
val_rmse = mean_squared_error(y_test, val_preds, squared=False)
ridge_model.score(X_test,y_test) #R^2
print('RMSE Score on test data',val_rmse)
print('RMSE Score on train data',train_rmse)
train_wmae = WMAE(X_train, y_train, train_preds)
print('The WMAE loss for the training set is  {}.'.format(train_wmae))
# Compute WMAE on validation data
val_wmae = WMAE(X_test, y_test, val_preds)
print('The WMAE loss for the validation set is  {}.'.format(val_wmae))

# %%
import matplotlib.pyplot as plt
import seaborn as sns
importance_df = pd.DataFrame({
    'feature': X_train.columns,
    'importance': tree.feature_importances_
}).sort_values('importance', ascending=False)

plt.figure(figsize=(4,2))
plt.title('Feature Importance')
sns.barplot(data=importance_df, x='importance', y='feature');

# %%
from sklearn.ensemble import RandomForestRegressor
rf1 = RandomForestRegressor(n_jobs=-1, random_state=42)
rfmodel=rf1.fit(X_train,y_train)

# %%
train_preds = rfmodel.predict(X_train)
val_preds = rfmodel.predict(X_test)
train_rmse = mean_squared_error(y_train, train_preds, squared=False)
val_rmse = mean_squared_error(y_test, val_preds, squared=False)
rfmodel.score(X_test,y_test) #R^2
print('RMSE Score on test data',val_rmse)
print('RMSE Score on train data',train_rmse)
train_wmae = WMAE(X_train, y_train, train_preds)
print('The WMAE loss for the training set is  {}.'.format(train_wmae))
# Compute WMAE on validation data
val_wmae = WMAE(X_test, y_test, val_preds)
print('The WMAE loss for the validation set is  {}.'.format(val_wmae))

# %%
from sklearn.model_selection import GridSearchCV
log_rf = RandomForestRegressor()
# Set the parameters by cross-validation
param_grid = {'n_estimators' : [100,150], 'max_depth': [20,30],
'min_samples_split': [3,5,7]}
cv = GridSearchCV(estimator = log_rf, param_grid = param_grid, cv = 5)
rf_svc_model = cv.fit(X_train, y_train)
print(rf_svc_model.best_params_)
print(rf_svc_model.best_estimator_)
print(rf_svc_model.best_score_)

# %%
rffinal = RandomForestRegressor(n_estimators = 100,min_samples_split=3,max_depth=40)
rfmodelfinal=rffinal.fit(X_train,y_train)

# %%
train_preds = rf_svc_model.predict(X_train)
val_preds = rf_svc_model.predict(X_test)
train_rmse = mean_squared_error(y_train, train_preds, squared=False)
val_rmse = mean_squared_error(y_test, val_preds, squared=False)
rf_svc_model.score(X_test,y_test) #R^2
print('RMSE Score on test data',val_rmse)
print('RMSE Score on train data',train_rmse)
train_wmae = WMAE(X_train, y_train, train_preds)
print('The WMAE loss for the training set is  {}.'.format(train_wmae))
# Compute WMAE on validation data
val_wmae = WMAE(X_test, y_test, val_preds)
print('The WMAE loss for the validation set is  {}.'.format(val_wmae))

# %%
gbm = XGBRegressor(random_state=42, n_jobs=-1)
gbmmodel=gbm.fit(train_inputs, train_targets)

# %%
train_preds = gbmmodel.predict(X_train)
val_preds = gbmmodel.predict(X_test)
train_rmse = mean_squared_error(y_train, train_preds, squared=False)
val_rmse = mean_squared_error(y_test, val_preds, squared=False)
gbmmodel.score(X_test,y_test) #R^2
print('RMSE Score on test data',val_rmse)
print('RMSE Score on train data',train_rmse)
train_wmae = WMAE(X_train, y_train, train_preds)
print('The WMAE loss for the training set is  {}.'.format(train_wmae))
# Compute WMAE on validation data
val_wmae = WMAE(X_test, y_test, val_preds)
print('The WMAE loss for the validation set is  {}.'.format(val_wmae))

# %%
from sklearn.model_selection import GridSearchCV
XGB = XGBRegressor()
# Set the parameters by cross-validation
param_grid = {'n_estimators':{50,100}, 'max_depth': [10,20], 'learning_rate' : [0.5,0.8,0.35]}
cv = GridSearchCV(estimator = XGB, param_grid = param_grid, cv = 5)
xgb_model = cv.fit(X_train, y_train)
print(xgb_model.cv_results_)
